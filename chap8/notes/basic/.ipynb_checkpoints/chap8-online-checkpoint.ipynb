# %%
import objgraph

# %%
x = 100
y = 100
objgraph.show_refs([x, y])

# %%
li1 = [1,2]
li2 = [1,2]
objgraph.show_refs([li1, li2])

# %%
li1.append(5)
print(li2)
# Out:
# [1, 2]

# %%
objgraph.show_refs([li1, li2])

# %%
li3 = li1

# %%
li1.extend([4,5])

# %%
li3
# Out:
# [1, 2, 5, 4, 5]

# %%
objgraph.show_refs([li1, li2, li3])

# %%
li1.append([2,3])

# %%
li4 = li1[:]

# %%
objgraph.show_refs([li1, li4])

# %%
li1[-1].append(8)

# %%
objgraph.show_refs([li1, li4])

# %%
li1[1] = 20

# %%
objgraph.show_refs([li1, li4])

# %%
s = {[2,3,4], 1, 2}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-e54c5a367903> in <module>
# ----> 1 s = {[2,3,4], 1, 2}
#
# TypeError: unhashable type: 'list'

# %%
d = 1.4

# %%
d.__hash__()
# Out:
# 922337203685477377

# %%
t = (1,2,3,[2,3,1])

# %%
d = {}
d[t] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-4f8aa08fe03e> in <module>
#       1 d = {}
# ----> 2 d[t] = 4
#
# TypeError: unhashable type: 'list'

# %%
hash(None)
# Out:
# 5903981416183

# %%
None.__hash__()
# Out:
# 5903981416183

# %%
a=3; b=5

# %%
print("%s %d" %(a,b))
print("{b:10.1} {a:10.1}".format(a=3, b=5))

# %%
print(f"{a} is greater than {b}")
# Out:
# 3 is greater than 5

# %%
f-string

# %%
def f(a, b, c, /):
    return a + b + c

# %%
f(a=1,b=2,c=3)
# Out:
# 6

# %%
f(1,2,3)
# Out:
# 6

# %%
f(b=1, a=3, c=2)
# Out:
# 6

# %%
f(a=1, 2, 3)
# Out:
#   File "<ipython-input-42-63e9f925a5dc>", line 1
#     f(a=1, 2, 3)
#           ^
# SyntaxError: positional argument follows keyword argument

# %%
args = [2,3,4]
f(*args)
# Out:
# 9
